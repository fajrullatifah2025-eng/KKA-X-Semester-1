# %% [markdown]
# <a href="https://colab.research.google.com/github/fajrullatifah2025-eng/KKA-X-Semester-1/blob/main/_Variabel_FajrulLatifah_X_5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Nama: Fajrul Latifah
#
# Kelas: X.5
#
# No. absen: 13

# %%
print("fajrullatifah@gmail.com")
print("fajrullatifah@gmail.com")
print("fajrullatifah@gmail.com")
# Out:
# fajrullatifah@gmail.com
# fajrullatifah@gmail.com
# fajrullatifah@gmail.com

# %%
email_user_1 = "fajrullatifah@gmail.com"

print(email_user_1)
print(email_user_1)
print(email_user_1)
# Out:
# fajrullatifah@gmail.com
# fajrullatifah@gmail.com
# fajrullatifah@gmail.com

# %% [markdown]
# Peraturan Penulisan Variabel

# %%
email user 2 = "latifafafa@gmail.com"

print(email user 2)
# Out:
#   File "/tmp/ipython-input-1162624191.py", line 1
#     email user 2 = "latifafafa@gmail.com"
#           ^
# SyntaxError: invalid syntax

# %%
#Hanya boleh menggunakan angka, huruf dan underscore

emailuser2 = "latifafafa@gmail.com"

print(emailuser2)
# Out:
# latifafafa@gmail.com

# %%
email_user_2 = "latifafafa@gmail.com"

print(email_user_2)
# Out:
# latifafafa@gmail.com

# %%
3_email_user = "ifafafa@gmail.com"

print(3_email_user)
# Out:
#   File "/tmp/ipython-input-3971684787.py", line 1
#     3_email_user = "ifafafa@gmail.com"
#      ^
# SyntaxError: invalid decimal literal

# %%
Tidak boleh didahului oleh angka
email_user_3 = "ifafafa@gmail.com"

print(email_user_3)
# Out:
#   File "/tmp/ipython-input-3168543875.py", line 1
#     Tidak boleh didahului oleh angka
#           ^
# SyntaxError: invalid syntax

# %%
Email_User_4 = "ifahaha@gmail.com"

print(email_user_4)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-4213625269.py in <cell line: 0>()
#       1 Email_User_4 = "ifahaha@gmail.com"
#       2
# ----> 3 print(email_user_4)
#
# NameError: name 'email_user_4' is not defined

# %%
Penulisan Variabel Sensitif Terhadap Kapital

Email_User_4 = "ifahaha@gmail.com"

print(Email_User_4)
# Out:
#   File "/tmp/ipython-input-466706626.py", line 1
#     Penulisan Variabel Sensitif Terhadap Kapital
#               ^
# SyntaxError: invalid syntax

# %%
if = "nopalala@gmail.com"

print(if)
# Out:
#   File "/tmp/ipython-input-3337256780.py", line 1
#     if = "nopalala@gmail.com"
#        ^
# SyntaxError: invalid syntax

# %%
If = "nopalala@gmail.com"

print(If)
# Out:
# nopalala@gmail.com

# %%
print = "nopapal@gmail.com"

print(print)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-4242315658.py in <cell line: 0>()
#       1 print = "nopapal@gmail.com"
#       2
# ----> 3 print(print)
#
# TypeError: 'str' object is not callable

# %%
Print = "nopapal@gmail.com"

print(Print)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-3968878582.py in <cell line: 0>()
#       1 Print = "nopapal@gmail.com"
#       2
# ----> 3 print(Print)
#
# TypeError: 'str' object is not callable

# %%
Harus deskriptif meski tidak error
_ = "latiti@Gmail.com"

print(_)
# Out:
#   File "/tmp/ipython-input-245377113.py", line 1
#     Harus deskriptif meski tidak error
#           ^
# SyntaxError: invalid syntax

# %%
_ = "lapapa@Gmail.com"

print(_)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-1418802521.py in <cell line: 0>()
#       1 _ = "lapapa@Gmail.com"
#       2
# ----> 3 print(_)
#
# TypeError: 'str' object is not callable

# %%
print(_)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-3119395983.py in <cell line: 0>()
# ----> 1 print(_)
#
# TypeError: 'str' object is not callable

# %%
print(i)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-3925571382.py in <cell line: 0>()
# ----> 1 print(i)
#
# NameError: name 'i' is not defined

# %% [markdown]
# Assignment

# %% [markdown]
# Aritmatika

# %% [markdown]
# Jenis Tipe Variabel pada Python

# %%
#Float
x = 17.5
print(x)
type(x)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-1298060847.py in <cell line: 0>()
#       1 #Float
#       2 x = 17.5
# ----> 3 print(x)
#       4 type(x)
#
# TypeError: 'str' object is not callable

# %%
#Integer
y = 8
print(y)
type(y)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-1004582950.py in <cell line: 0>()
#       1 #Integer
#       2 y = 8
# ----> 3 print(y)
#       4 type(y)
#
# TypeError: 'str' object is not callable

# %%
#String
z = "fajrul"
print(z)
type(z)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-3326925848.py in <cell line: 0>()
#       1 #String
#       2 z = "fajrul"
# ----> 3 print(z)
#       4 type(z)
#
# TypeError: 'str' object is not callable

# %%
#Boolean
p = True
print(p)
type(p)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-1037090062.py in <cell line: 0>()
#       1 #Boolean
#       2 p = True
# ----> 3 print(p)
#       4 type(p)
#
# TypeError: 'str' object is not callable

# %%
r = -2.5
print(r)
type(r)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-490536173.py in <cell line: 0>()
#       1 r = -2.5
# ----> 2 print(r)
#       3 type(r)
#
# TypeError: 'str' object is not callable

# %%
s = 5.1
print(s)
type(s)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-1904761672.py in <cell line: 0>()
#       1 s = 5.1
# ----> 2 print(s)
#       3 type(s)
#
# TypeError: 'str' object is not callable

# %%
k = '%7akh3.'
print(k)
type(k)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-3146244300.py in <cell line: 0>()
#       1 k = '%7akh3.'
# ----> 2 print(k)
#       3 type(k)
#
# TypeError: 'str' object is not callable

# %% [markdown]
# Mengubah Tipe Data

# %%
a = 25
print(a)
type(a)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-1784430839.py in <cell line: 0>()
#       1 a = 25
# ----> 2 print(a)
#       3 type(a)
#
# TypeError: 'str' object is not callable

# %%
a = float(a)
print(a)
type(a)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-3962232315.py in <cell line: 0>()
#       1 a = float(a)
# ----> 2 print(a)
#       3 type(a)
#
# TypeError: 'str' object is not callable

# %%
a = str(a)
print(a)
type(a)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-3821863648.py in <cell line: 0>()
#       1 a = str(a)
# ----> 2 print(a)
#       3 type(a)
#
# TypeError: 'str' object is not callable

# %%
a = bool(a)
print(a)
type(a)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-161547671.py in <cell line: 0>()
#       1 a = bool(a)
# ----> 2 print(a)
#       3 type(a)
#
# TypeError: 'str' object is not callable

# %%
b = True
print(b)
type(b)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-1340759451.py in <cell line: 0>()
#       1 b = True
# ----> 2 print(b)
#       3 type(b)
#
# TypeError: 'str' object is not callable

# %%
b = int(b)
print(b)
type(b)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-903555575.py in <cell line: 0>()
#       1 b = int(b)
# ----> 2 print(b)
#       3 type(b)
#
# TypeError: 'str' object is not callable

# %%
b = float(b)
print(b)
type(b)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-2688239477.py in <cell line: 0>()
#       1 b = float(b)
# ----> 2 print(b)
#       3 type(b)
#
# TypeError: 'str' object is not callable

# %%
b = str(b)
print(b)
type(b)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-2594274079.py in <cell line: 0>()
#       1 b = str(b)
# ----> 2 print(b)
#       3 type(b)
#
# TypeError: 'str' object is not callable

# %%
c = False
print(c)
type(c)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-778869892.py in <cell line: 0>()
#       1 c = False
# ----> 2 print(c)
#       3 type(c)
#
# TypeError: 'str' object is not callable

# %%
c = float(c)
print(c)
type(c)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-3168067449.py in <cell line: 0>()
#       1 c = float(c)
# ----> 2 print(c)
#       3 type(c)
#
# TypeError: 'str' object is not callable

# %%
c = int(c)
print(c)
type(c)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-4221954543.py in <cell line: 0>()
# ----> 1 c = int(c)
#       2 print(c)
#       3 type(c)
#
# ValueError: invalid literal for int() with base 10: '0.0'

# %%
c = str(c)
print(c)
type(c)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-698934447.py in <cell line: 0>()
#       1 c = str(c)
# ----> 2 print(c)
#       3 type(c)
#
# TypeError: 'str' object is not callable

# %% [markdown]
# Operator Perbandingan
