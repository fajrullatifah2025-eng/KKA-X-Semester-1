# %% [markdown]
# <a href="https://colab.research.google.com/github/fajrullatifah2025-eng/KKA-X-Semester-1/blob/main/1_Fajrul_Latifah_X_5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #1.Menampilkan Teks Bebas

# %% [markdown]
# 1.Menampilkan Teks Bebas

# %% [markdown]
# Escape Character

# %%
print("Hello World")
# Out:
# Hello World

# %%
print("Fajrul Latifah")
# Out:
# Fajrul Latifah

# %% [markdown]
# #2.Menampilkan Nilai Variabel

# %%
tinggibadan = 150
print(tinggibadan)
# Out:
# 150

# %%
beratBadan = 45
print(beratBadan)
# Out:
# 45

# %%
nama = "Fajrul Latifah"
print(nama)
# Out:
# Fajrul Latifah

# %% [markdown]
# #3.Menampilkan Teks Bebas dan Nilai Variabel

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-1412707250.py in <cell line: 0>()
# ----> 1 print("Halo nama saya", nama,".Berat badan saya",beratBadan, "Kg.")
#
# NameError: name 'nama' is not defined

# %% [markdown]
# #4.Escape Character

# %%
print("Nama:Fajrul Latifah")
print("Kelas:X.5")
print("No.abs:13")
# Out:
# Nama:Fajrul Latifah
# Kelas:X.5
# No.abs:13

# %%
print("""Nama\t\t:Fajrul Latifah
Kelas\t\t: X-5
No. Absen\t: 2""")
# Out:
# Nama		:Fajrul Latifah
# Kelas		: X-5
# No. Absen	: 2

# %%
print("Nama: Fajrul Latifah\nKelas: X-5\nNo. Absen: 2")
# Out:
# Nama: Fajrul Latifah
# Kelas: X-5
# No. Absen: 2

# %%
print('Nama Saya Ja\'far Shodiq')
# Out:
# Nama Saya Ja'far Shodiq

# %%
print("Nama Saya Ja'far Shodiq")
# Out:
# Nama Saya Ja'far Shodiq

# %%
print("Nama Saya Ja\'far Shodiq")

# %%
print('Bu Shinta berkata, "Tolong perhatikan TV dan Saya."')
# Out:
# Bu Shinta berkata, "Tolong perhatikan TV dan Saya."

# %%
print("Bu Shinta berkata, \"Tolong perhatikan TV dan Saya.\"")
# Out:
# Bu Shinta berkata, "Tolong perhatikan TV dan Saya."

# %% [markdown]
# #PARAMETER FUNGSI PRINT

# %%
nama_sisiswaswa_1 = "Jielo"
nama_siswa_2 = "Aida"
nama_siswa_3 = "Dani"
nama_siswa_4 = "Nurul"

print(nama_siswa_1, end="/")
print(nama_siswa_2, end="/")
print(nama_siswa_3, end="/")
print(nama_siswa_4)
# Out:
# Jielo/Aida/Dani/Nurul

# %%
nama_siswa_5 = "Hasbi"
nama_siswa_6 = "Habibi"
nama_siswa_7 = "Rendra"
nama_siswa_8 = "Naufal"

print(nama_siswa_8, nama_siswa_7, nama_siswa_6, nama_siswa_5, sep="*")
# Out:
# Naufal*Rendra*Habibi*Hasbi

# %%
nama_siswa_5 = "Hasbi"
nama_siswa_6 = "Habibi"
nama_siswa_7 = "Rendra"
nama_siswa_8 = "Naufal"

print(nama_siswa_8, nama_siswa_7, nama_siswa_5, nama_siswa_6, sep="-")
# Out:
# Naufal-Rendra-Hasbi-Habibi
